# %%
import os
import pandas as pd
import csv
import re
import sys
import math
import nltk
import string
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk import word_tokenize
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords

# %%
## Retrieve current working directory (`cwd`)
cwd = os.getcwd()
cwd
## Change directory 
current_file=os.chdir("C:\\treckchallenge")

# %% [markdown]
# # Reading the Data

# %%
# Load the data from excel in csv format
data_with_features= pd.read_csv("C:\\treckchallenge\\20180622processedGoldStandardXMLTXT.tsv", sep="\t", encoding="utf-8", usecols=["pm_rel_desc", "title", "abstract", "trec_topic_disease"])
data_with_features.shape
# Out:
# (22642, 4)

# %% [markdown]
# # Getting Stop Words

# %%
#download stopwords
nltk.download('stopwords')
stop = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Arpita.Kappattanavar\AppData\Roaming\nltk_dat
# [nltk_data]     a...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Creating PM dataset

# %%
pmSet = data_with_features[data_with_features['pm_rel_desc'].str.contains('Human PM|Animal PM', regex=True)]
pmSet.shape
# Out:
# (9274, 4)

# %% [markdown]
# # Something

# %%
nltk.download('punkt')

# Convert the data to lower case 
PM_abstract_title = pmSet['title'].str.lower() + ' ' + pmSet['abstract'].str.lower()


# Removed stop words and punctuations
PM_no_stopWords = []
for text in PM_abstract_title:
    words = word_tokenize(text)
    for word in words:
        if word not in stopwords.words('english') and word not in string.punctuation:
            PM_no_stopWords.append(word)

PM_no_stopWords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Arpita.Kappattanavar\AppData\Roaming\nltk_dat
# [nltk_data]     a...
# [nltk_data]   Package punkt is already up-to-date!
# ['case',
#  'metastatic',
#  'liposarcoma',
#  'originating',
#  'retroperitoneum',
#  'successfully',
#  'treated',
#  'combination',
#  'chemotherapy',
#  'reported',
#  '36-year-old',
#  'woman',
#  'metastatic',
#  'liposarcoma',
#  'originating',
#  'retroperitoneum',
#  'responded',
#  'well',
#  'adjuvant',
#  'chemotherapy',
#  'primary',
#  'tumor',
#  'removed',
#  'surgery',
#  'two',
#  'months',
#  'later',
#  'patient',
#  'developed',
#  'metastasis',
#  'brain',
#  'lung',
#  'four',
#  'months',
#  'later',
#  'metastatic',
#  'liposarcomas',
#  'brain',
#  'generally',
#  'extremely',
#  'rare',
#  'patient',
#  'treated',
#  'combination',
#  'chemotherapy',
#  'using',
#  'cyclophosphamide',
#  'vincristine',
#  'adriamycin',
#  'dacarbazine',
#  'cyvadic',
#  'examined',
#  'former',
#  'two',
#  'drugs',
#  'alternated',
#  'vindesine',
#  'ifosfamide',
#  'another',
#  'regimen',
#  'cisplatin',
#  'etoposide',
#  'given',
#  'three-week',
#  'interval',
#  'result',
#  'metastases',
#  'totally',
#  'disappeared',
#  'recurrent',
#  'lesion',
#  'noted',
#  'two',
#  'years',
#  'although',
#  'role',
#  'chemotherapy',
#  'liposarcoma',
#  'well',
#  'defined',
#  'little',
#  'data',
#  'support',
#  'use',
#  'adjuvant',
#  'setting',
#  'combination',
#  'chemotherapy',
#  'seemed',
#  'effective',
#  'advanced',
#  'liposarcoma',
#  'analysis',
#  'sas',
#  'gene',
#  'cdk4',
#  'mdm2',
#  'proteins',
#  'low-grade',
#  'osteosarcoma',
#  'region',
#  'q13-15',
#  'chromosome',
#  '12',
#  'contains',
#  'sas',
#  'cdk4',
#  'mdm2',
#  'genes',
#  'rearranged',
#  'amplified',
#  'variety',
#  'human',
#  'sarcomas',
#  'study',
#  'evaluated',
#  'sas',
#  'gene',
#  'amplification',
#  'mdm2',
#  'cdk4',
#  'protein',
#  'expression',
#  '20',
#  'tumor',
#  'samples',
#  'central',
#  'low-grade',
#  'osteosarcoma',
#  '16',
#  'primary',
#  '3',
#  'recurrences',
#  '1',
#  'lung',
#  'metastasis',
#  'sas',
#  'amplification',
#  'analyzed',
#  'quantitative',
#  'polymerase',
#  'chain',
#  'reaction',
#  'pcr',
#  'paraffin-embedded',
#  'samples',
#  'mdm2',
#  'cdk4',
#  'protein',
#  'expression',
#  'evaluated',
#  'immunohistochemistry',
#  'mdm2',
#  'cdk4',
#  'proteins',
#  'found',
#  'strongly',
#  'expressed',
#  '35',
#  '65',
#  'respectively',
#  'samples',
#  'sas',
#  'found',
#  'amplified',
#  '15',
#  'samples',
#  'findings',
#  'indicate',
#  'genes',
#  'may',
#  'involved',
#  'tumorigenesis',
#  'progression',
#  'low-grade',
#  'osteosarcoma',
#  'induction',
#  'secreted',
#  'protein',
#  'myxoid',
#  'liposarcoma',
#  'oncogene',
#  'tls-chop',
#  'oncoprotein',
#  'found',
#  'majority',
#  'human',
#  'myxoid',
#  'liposarcomas',
#  'consists',
#  'fusion',
#  'transcription',
#  'factor',
#  'chop/gadd153',
#  'n',
#  'terminus',
#  'rna-binding',
#  'protein',
#  'tls/fus',
#  'clinical',
#  'correlation',
#  'vitro',
#  'transformation',
#  'assays',
#  'indicate',
#  'n',
#  'terminus',
#  'tls',
#  'plays',
#  'important',
#  'role',
#  'oncogenesis',
#  'tls-chop',
#  'however',
#  'activity',
#  'attributed',
#  'oncoprotein',
#  'inhibiting',
#  'binding',
#  'transcription',
#  'factors',
#  'c/ebp',
#  'class',
#  'certain',
#  'adipogenic',
#  'target',
#  'genes',
#  'function',
#  'tls-chop',
#  'shares',
#  'nononcogenic',
#  'chop',
#  'protein',
#  'report',
#  'isolation',
#  'gene',
#  'dol54',
#  'activated',
#  'primary',
#  'fibroblasts',
#  'expression',
#  'tls-chop',
#  'dol54',
#  'expressed',
#  'neoplastic',
#  'component',
#  'human',
#  'myxoid',
#  'liposarcomas',
#  'increases',
#  'tumorigenicity',
#  'cells',
#  'injected',
#  'nude',
#  'mice',
#  'activation',
#  'dol54',
#  'requires',
#  'intact',
#  'dna-binding',
#  'dimerization',
#  'domain',
#  'tls-chop',
#  'suitable',
#  'cellular',
#  'dimerization',
#  'partner',
#  'depends',
#  'tls',
#  'n',
#  'terminus',
#  'normal',
#  'adipocytic',
#  'differentiation',
#  'associated',
#  'early',
#  'transient',
#  'expression',
#  'dol54',
#  'gene',
#  'encodes',
#  'secreted',
#  'protein',
#  'tightly',
#  'associated',
#  'cell',
#  'surface',
#  'extracellular',
#  'matrix',
#  'tls-chop',
#  'thus',
#  'leads',
#  'unscheduled',
#  'expression',
#  'gene',
#  'normally',
#  'associated',
#  'adipocytic',
#  'differentiation',
#  'mutations',
#  'tp53',
#  'amplification',
#  'egfr',
#  'mdm2',
#  'cdk4',
#  'deletions',
#  'cdkn2a',
#  'malignant',
#  'astrocytomas',
#  'investigated',
#  'frequency',
#  'mutual',
#  'relationship',
#  'molecular',
#  'alterations',
#  '33',
#  'malignant',
#  'astrocytomas',
#  '28',
#  'glioblastomas',
#  '5',
#  'anaplastic',
#  'astrocytomas',
#  'genetic',
#  'alterations',
#  'analyzed',
#  'deletion',
#  'cdkn2a/p16',
#  'gene',
#  'tp53',
#  'mutations',
#  'amplification',
#  'egfr',
#  'mdm2',
#  'cdk4',
#  'common',
#  'genetic',
#  'alteration',
#  'egfr',
#  'amplification',
#  'revealed',
#  '15',
#  'cases',
#  '45',
#  'tp53',
#  'mutation',
#  'identified',
#  '9',
#  'cases',
#  '27',
#  'cdkn2/p16',
#  'deletion',
#  'detected',
#  '13',
#  'cases',
#  '41',
#  'either',
#  'mdm2',
#  'cdk4',
#  'amplifications',
#  'less',
#  'frequent',
#  'identified',
#  '4',
#  '12',
#  '1',
#  '3',
#  'case',
#  'respectively',
#  '15',
#  'cases',
#  'showing',
#  'amplification',
#  'egfr',
#  '9',
#  'cdkn2/p16',
#  'deletion',
#  '60',
#  'p',
#  '0.04',
#  'hand',
#  'cdkn2/p16',
#  'deletion',
#  'egfr',
#  'amplification',
#  'rarely',
#  'occurred',
#  'tp53',
#  'mutations',
#  '2',
#  '14',
#  'cases',
#  'cdkn2/p16',
#  'deletion',
#  '14',
#  'results',
#  'confirm',
#  'existence',
#  'least',
#  'two',
#  'different',
#  'pathways',
#  'leading',
#  'formation',
#  'glioblastoma',
#  'case',
#  'advanced',
#  'retroperitoneal',
#  'dedifferentiated',
#  'liposarcoma',
#  'treated',
#  'effectively',
#  'high-dose',
#  'ifosfamide',
#  'report',
#  'case',
#  'retroperitoneal',
#  'dedifferentiated',
#  'liposarcoma',
#  'treated',
#  'effectively',
#  'high-dose',
#  'ifosfamide',
#  '59-year-old',
#  'man',
#  'received',
#  'tumorectomy',
#  'right',
#  'nephrectomy',
#  'retroperitoneal',
#  'liposarcoma',
#  'twenty-two',
#  'months',
#  'operation',
#  'liver',
#  'metastasis',
#  'resected',
#  'incompletely',
#  'three',
#  'months',
#  'later',
#  'right',
#  'pleural',
#  'retroperitoneal',
#  'peritoneal',
#  'metastases',
#  'appeared',
#  '6',
#  'cycles',
#  'high-dose',
#  'ifosfamide',
#  'therapy',
#  'tumors',
#  'reduced',
#  'partially',
#  'ten',
#  'cycles',
#  'chemotherapy',
#  'administered',
#  'tumors',
#  'showed',
#  'regrowth',
#  '14',
#  'months',
#  'administration',
#  'high',
#  'dose',
#  'ifosfamide',
#  'combination',
#  'chemotherapy',
#  'ifosfamide',
#  'doxorubicine',
#  'etoposide',
#  'effective',
#  'regrowth',
#  'tumors',
#  'detection',
#  'p16',
#  'rb',
#  'cdk4',
#  'p53',
#  'gene',
#  'deletion',
#  'amplification',
#  'fluorescence',
#  'situ',
#  'hybridization',
#  '96',
#  'gliomas',
#  'inactivation',
#  'p53',
#  'gene',
#  'common',
#  'early',
#  'event',
#  'astrocytoma',
#  'tumorigenesis',
#  'alternatively',
#  'since',
#  'p16',
#  'retinoblastoma',
#  'rb',
#  'cdk4',
#  'genes',
#  'implicated',
#  'malignant',
#  'progression',
#  'detection',
#  'losses',
#  'amplifications',
#  'genes',
#  'gliomas',
#  'could',
#  'diagnostically',
#  'prognostically',
#  'therapeutically',
#  'important',
#  'obtained',
#  'smear',
#  'preparations',
#  '96',
#  'diffuse',
#  'gliomas',
#  '10',
#  'nonneoplastic',
#  'specimens',
#  'dual-color',
#  'fluorescence',
#  'situ',
#  'hybridizations',
#  'using',
#  'paired',
#  'probes',
#  'cen9/p16',
#  'cen8/rb',
#  'cen17/p53',
#  'cen12/cdk4',
#  'performed',
#  'revealed',
#  'expected',
#  'frequencies',
#  'abnormalities',
#  'except',
#  'p53',
#  'losses',
#  'low',
#  '7',
#  'latter',
#  'supports',
#  'concept',
#  'p53',
#  'inactivation',
#  'usually',
#  'occurs',
#  'mitotic',
#  'recombination',
#  'detected',
#  'abnormalities',
#  'p16/rb/cdk4',
#  'pathway',
#  'highly',
#  'associated',
#  'astrocytic',
#  'differentiation',
#  'univariately',
#  'associated',
#  'decreased',
#  'patient',
#  'survival',
#  'however',
#  'patient',
#  'age',
#  'histologic',
#  'classification',
#  'retained',
#  'statistical',
#  'significance',
#  'multivariate',
#  'analysis',
#  'conclude',
#  'diffuse',
#  'gliomas',
#  'p16/rb/cdk4',
#  'abnormalities',
#  'markers',
#  'astrocytic',
#  'phenotype',
#  'thus',
#  'detection',
#  'fluorescence',
#  'situ',
#  'hybridization',
#  'may',
#  'diagnostic',
#  'usefulness',
#  'cases',
#  'equivocal',
#  'morphologic',
#  'features',
#  'although',
#  'numbers',
#  'small',
#  'find',
#  'additional',
#  'prognostic',
#  'significance',
#  'genetic',
#  'abnormalities',
#  'one',
#  'age',
#  'grade',
#  'oligodendroglial',
#  'histology',
#  'taken',
#  'account',
#  'expression',
#  'mdm2/cdk4',
#  'gene',
#  'product',
#  'differential',
#  'diagnosis',
#  'well',
#  'differentiated',
#  'liposarcoma',
#  'large',
#  'deep-seated',
#  'lipoma',
#  'ordinary',
#  'lipomas',
#  'cytogenetically',
#  'characterized',
#  'variety',
#  'balanced',
#  'rearrangements',
#  'involving',
#  'chromosome',
#  'segment',
#  '12q13-15',
#  'whereas',
#  'well',
#  'differentiated',
#  'liposarcomas',
#  'wdl',
#  'show',
#  'supernumerary',
#  'ring',
#  'giant',
#  'marker',
#  'chromosomes',
#  'known',
#  'contain',
#  'amplified',
#  '12q',
#  'sequences',
#  'tight',
#  'correlation',
#  'presence',
#  'ring',
#  'chromosomes',
#  'amplification',
#  'overexpression',
#  'mdm2',
#  'cdk4',
#  'genes',
#  'suggests',
#  'exploration',
#  'possibility',
#  'immunocytochemistry',
#  'icc',
#  'might',
#  'assist',
#  'differential',
#  'diagnosis',
#  'lipoma-like',
#  'well',
#  'differentiated',
#  'liposarcomas',
#  'll-wdl',
#  'large',
#  'deep-seated',
#  'lipomas',
#  'ldsl',
#  'purpose',
#  '21',
#  'cases',
#  'former',
#  '19',
#  'cases',
#  'latter',
#  'tumours',
#  'analysed',
#  'icc',
#  'according',
#  'availability',
#  'material',
#  'molecular',
#  'cytogenetic',
#  'approaches',
#  'lipomas',
#  'displayed',
#  'null',
#  'mdm2/cdk4',
#  'phenotype',
#  'whereas',
#  'll-wdl',
#  'showed',
#  'mdm2/cdk4',
#  'cdk4',
#  'phenotypes',
#  'southern',
#  'blot',
#  'analysis',
#  'performed',
#  '16',
#  'suitable',
#  'cases',
#  'complemented',
#  'fluorescence',
#  'situ',
#  'hybridization',
#  'classical',
#  'cytogenetic',
#  'analysis',
#  '11',
#  'cases',
#  'consistent',
#  'supported',
#  'immunophenotyping',
#  'data',
#  'conclusion',
#  'mdm2/cdk4',
#  'product-based',
#  'immunophenotyping',
#  'appears',
#  'represent',
#  'valuable',
#  'method',
#  'categorization',
#  'arguable',
#  'ldsl',
#  'myxoid',
#  'liposarcoma',
#  '12-year-old',
#  'girl',
#  '12-year-old',
#  'girl',
#  'developed',
#  'myxoid',
#  'liposarcoma',
#  'inner',
#  'side',
#  'right',
#  'thigh',
#  'liposarcomas',
#  'extremely',
#  'rare',
#  'age',
#  'compared',
#  'benign',
#  'lipoblastomas',
#  'frequent',
#  'tumors',
#  'fatty',
#  'tissue',
#  'childhood',
#  'prognosis',
#  'myxoid',
#  'liposarcoma',
#  'good',
#  'especially',
#  'patient',
#  'tumor',
#  'located',
#  'subcutis',
#  'large',
#  'deep',
#  'excision',
#  'possible',
#  'often',
#  'curative',
#  'morphologic-cytogenetic',
#  'analysis',
#  'dedifferentiated',
#  'liposarcomas',
#  'extensive',
#  'misleading',
#  'leiomyosarcomatous',
#  'component',
#  'report',
#  'describes',
#  'two',
#  'cases',
#  'recurrent',
#  'retroperitoneal',
#  'dedifferentiated',
#  'liposarcoma',
#  'characterized',
#  'extensive',
#  'leiomyomatous',
#  'component',
#  'prevented',
#  'correct',
#  'diagnosis',
#  'last',
#  'recurrence',
#  'strong',
#  'immunoreactivity',
#  'smooth',
#  'muscle',
#  'desmin',
#  'antibodies',
#  'ultrastructural',
#  'features',
#  'consistent',
#  'leiomyosarcoma',
#  'observed',
#  'spindle-cell',
#  'and/or',
#  'myxoid-like',
#  'components',
#  'four',
#  'recurrences',
#  'case',
#  '1',
#  'spindle-cell',
#  'component',
#  'primary',
#  'tumor',
#  'first',
#  'recurrence',
#  'case',
#  '2.',
#  'case',
#  '1',
#  'correct',
#  'diagnosis',
#  'suggested',
#  'cytogenetic',
#  'evidence',
#  'ring',
#  'markers',
#  'hallmark',
#  'well-differentiated/dedifferentiated',
#  'liposarcoma',
#  'case',
#  '2',
#  'tumor',
#  'type',
#  'yielded',
#  'mainly',
#  'morphology',
#  'second',
#  'recurrence',
#  'consisted',
#  'entirely',
#  'well-differentiated',
#  'liposarcoma',
#  'sclerosing',
#  'inflammatory',
#  'variant',
#  'confirmed',
#  'karyotype',
#  'reevaluation',
#  'first',
#  'two',
#  'surgical',
#  'specimens',
#  'case',
#  'revealed',
#  'small',
#  'areas',
#  'consistent',
#  'well-differentiated',
#  'liposarcoma',
#  'previously',
#  'overlooked',
#  'despite',
#  'smooth-muscle',
#  'antigen',
#  'profile',
#  'cases',
#  'retained',
#  'mdm2+/p53+/cdk4+',
#  'immunophenotype',
#  'consistent',
#  'genotype',
#  'dedifferentiation',
#  'well-differentiated',
#  'liposarcoma',
#  'highly',
#  'malignant',
#  'metastatic',
#  'osteosarcoma',
#  'amplification',
#  '12q14',
#  'stages',
#  'gain',
#  '1q22-q24',
#  'associated',
#  'metastases',
#  'well-differentiated',
#  'liposarcomas',
#  'wdlps',
#  'especially',
#  'located',
#  'retroperitoneum',
#  'may',
#  'occasionally',
#  'undergo',
#  'dedifferentiation',
#  'although',
#  'process',
#  'associated',
#  'aggressive',
#  'clinical',
#  'course',
#  'dedifferentiated',
#  'liposarcomas',
#  'rarely',
#  'produces',
#  'metastases',
#  'case',
#  'reported',
#  'rather',
#  'uncommon',
#  'retroperitoneal',
#  'wdlps',
#  'gave',
#  'lung',
#  'metastases',
#  'diagnosed',
#  'highly',
#  'malignant',
#  'osteosarcomas',
#  'used',
#  'comparative',
#  'genomic',
#  'hybridization',
#  'cgh',
#  'fluorescence',
#  'situ',
#  'hybridization',
#  'fish',
#  'southern',
#  'blot',
#  'analyses',
#  'characterize',
#  'copy',
#  'number',
#  'changes',
#  'genetic',
#  'aberrations',
#  'occurring',
#  'different',
#  'stages',
#  'disease',
#  'primary',
#  'tumor',
#  'detectable',
#  'aberration',
#  'amplification',
#  '12q13-q14',
#  'present',
#  'fraction',
#  'cells',
#  'revealed',
#  'fish',
#  'analysis',
#  'high-level',
#  'amplification',
#  '12q13-q14',
#  'involving',
#  'cdk4',
#  'mdm2',
#  'hmgic',
#  'seen',
#  'relapse',
#  'metastases',
#  'second',
#  'common',
#  'change',
#  'gain',
#  'high-level',
#  'amplification',
#  '1q22-q24',
#  'detectable',
#  'cgh',
#  'osteogenic',
#  'metastases',
#  'loss',
#  'distal',
#  '2q',
#  'fish',
#  'analyses',
#  'revealed',
#  'considerable',
#  'heterogeneity',
#  'samples',
#  'percentage',
#  'cells',
#  ...]

# %%
# filter the stopwords from title
text3 = text2
text3 = ' '.join([word for word in text3.split() if word not in (stopwords.words('english'))])

# %%
# filter the stopwords from abstract
text4 = text1
text4 = ' '.join([word for word in text4.split() if word not in (stopwords.words('english'))])
print(text4)
# Out:
AUY922 erlotinib patients EGFR-mutant lung cancer acquired resistance (AR) EGFR tyrosine kinase inhibitors (EGFR TKIs). 18695 EGFR-TKI benefit NSCLC patients EML4-ALK rearrangement. 18696 Different EGFR/KRAS mutation spectrums lung cancer never smokers heavy smokers. 18697 A static diagnostic biopsy patients mutated EGFR lung adenocarcinom guide therapeutic decisions. 18698 Frequency clinical characterization NSCLC patients harboring PIK3CA mutations identified within regional screening network. 18699 Amplification fibroblast growth factor receptor type 1 gene (FGFR1) samples 101 NSCLC patients (pts) squamous cell carcinoma (SCC) histology. 18700 Clinical characteristics natural history patients squamous cell lung carcinoma FGFR1 amplification. 18701 Higher incidence EGFR exon 19 deletion younger (age 40 younger) patients adenocarcinoma lung. 18702 Tumor PIK3CA mutations, lymphocyte infiltration, recurrence-free survival (RFS) early breast cancer (BC): Results FinHER trial. 18703 Long-term survivors advanced nonsquamous non-small cell lung cancer (nsNSCLC) treated first-line (1L) chemotherapy (CT) plus bevacizumab (B) maint ...

# %%
#Cell to find top_words

def tokenize(text):
    tokens = word_tokenize(text)
    stems = []
    for item in tokens: stems.append(PorterStemmer().stem(item))
    return stems


# word tokenize and stem
text = [" ".join(tokenize(txt.lower())) for txt in text]
vectorizer = TfidfVectorizer()
matrix = vectorizer.fit_transform(text).todense()
# transform the matrix to a pandas df
matrix = pd.DataFrame(matrix, columns=vectorizer.get_feature_names())
# sum over each title and abstract (axis=0)
top_words = matrix.sum(axis=0).sort_values(ascending=False)
print(top_words)
# Out:
# patient              0.640964
# mutat                0.639770
# cancer               0.602994
# lung                 0.475828
# egfr                 0.394871
# cell                 0.393319
# kra                  0.285974
# tumor                0.269258
# the                  0.231884
# alk                  0.208361
# braf                 0.199048
# diseas               0.195824
# pt                   0.194510
# studi                0.188898
# carcinoma            0.178391
# amplif               0.163704
# fgfr1                0.156778
# breast               0.155226
# adenocarcinoma       0.148301
# human                0.146271
# therapi              0.133256
# melanoma             0.132062
# non                  0.123942
# result               0.120599
# pik3ca               0.120241
# treatment            0.117375
# nsclc                0.117017
# tki                  0.110091
# inhibitor            0.108897
# respons              0.105558
#                        ...
# dramat               0.002853
# drive                0.002853
# emphas               0.002853
# primit               0.002853
# privat               0.002853
# elimin               0.002853
# problem              0.002853
# electronmicroscop    0.002853
# electrocardiogram    0.002853
# product              0.002853
# eight                0.002853
# prognos              0.002853
# project              0.002853
# ecori                0.002853
# ecg                  0.002853
# prolong              0.002853
# promis               0.002853
# e746                 0.002853
# pronunc              0.002853
# e2f3                 0.002853
# proof                0.002853
# dy                   0.002853
# propos               0.002853
# propria              0.002853
# prostat              0.002853
# dual                 0.002853
# proteinuria          0.002853
# druggabl             0.002853
# prove                0.002853
# zytolight            0.002853
# Length: 2043, dtype: float64

# %% [markdown]
# # Creating not PM dataset

# %%
notPmSet = data_with_features[data_with_features['pm_rel_desc'].str.contains('Not PM', regex=True)]
notPmSet.shape
# Out:
# (13368, 4)
