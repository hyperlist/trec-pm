# %%
import pandas as pd

# %%
alldata = pd.read_csv("../../resources/20180622processedGoldStandardTopics.tsv.gz", delimiter="\t")
data = alldata.drop(["title", "abstract", "major_mesh", "minor_mesh"], axis=1)
data.head()
# Out:
#    Unnamed: 0  trec_topic_number trec_doc_id pm_rel_desc   disease_desc  \
# 0           0                  1    10065107    Human PM          Exact
# 1           1                  1    10101594    Human PM   More General
# 2           2                  1    10220412    Human PM  More Specific
# 3           3                  1    10323080    Human PM   More General
# 4           4                  1    10466061    Human PM          Exact
#
#   gene1_annotation_desc          gene1_name gene2_annotation_desc gene2_name  \
# 0          Missing Gene  CDK4 Amplification                   NaN        NaN
# 1                 Exact  CDK4 Amplification                   NaN        NaN
# 2          Missing Gene  CDK4 Amplification                   NaN        NaN
# 3                 Exact  CDK4 Amplification                   NaN        NaN
# 4          Missing Gene  CDK4 Amplification                   NaN        NaN
#
#   gene3_annotation_desc gene3_name demographics_desc     other_desc  \
# 0                   NaN        NaN           Matches  Not Discussed
# 1                   NaN        NaN     Not Discussed  Not Discussed
# 2                   NaN        NaN     Not Discussed  Not Discussed
# 3                   NaN        NaN     Not Discussed  Not Discussed
# 4                   NaN        NaN           Matches  Not Discussed
#
#    relevance_score trec_topic_disease trec_topic_age trec_topic_sex  \
# 0                0        Liposarcoma    38-year-old           male
# 1                1        Liposarcoma    38-year-old           male
# 2                0        Liposarcoma    38-year-old           male
# 3                1        Liposarcoma    38-year-old           male
# 4                0        Liposarcoma    38-year-old           male
#
#   trec_topic_other1 trec_topic_other2 trec_topic_other3
# 0              GERD               NaN               NaN
# 1              GERD               NaN               NaN
# 2              GERD               NaN               NaN
# 3              GERD               NaN               NaN
# 4              GERD               NaN               NaN

# %%
len(data.query("relevance_score > 0"))
# Out:
# 3875
