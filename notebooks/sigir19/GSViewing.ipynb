# %%
import pandas as pd

# %%
alldata = pd.read_csv("../../resources/20190111processedGoldStandardPub2018.tsv.gz", delimiter="\t")
data = alldata.drop(["title", "abstract", "major_mesh", "minor_mesh"], axis=1)
data.head()
# Out:
#    Unnamed: 0  trec_topic_number trec_doc_id pm_rel_desc   disease_desc  \
# 0           0                  1     1007359    Human PM  More Specific
# 1           1                  1    10833951    Human PM  More Specific
# 2           2                  1    11381855    Human PM  More Specific
# 3           3                  1     1234252      Not PM            NaN
# 4           4                  1     1234878      Not PM            NaN
#
#   gene1_annotation_desc    gene1_name gene2_annotation_desc gene2_name  \
# 0          Missing Gene  BRAF (V600E)                   NaN        NaN
# 1          Missing Gene  BRAF (V600E)                   NaN        NaN
# 2          Missing Gene  BRAF (V600E)                   NaN        NaN
# 3                   NaN           NaN                   NaN        NaN
# 4                   NaN           NaN                   NaN        NaN
#
#    gene3_annotation_desc  gene3_name demographics_desc     other_desc  \
# ...

# %%
len(data.query("relevance_score > 0"))
# Out:
# 5588
