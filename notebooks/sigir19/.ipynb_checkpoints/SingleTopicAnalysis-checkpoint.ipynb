# %%
import pandas as pd

# %%
allgsdf = pd.read_csv("../../resources/20180622processedGoldStandardTopics.tsv.gz", delimiter="\t")
gsdf = allgsdf.drop(["title", "abstract", "major_mesh", "minor_mesh"], axis=1)

# %%
resdf = pd.read_csv("../../results/genedispbnb.trec_results", delimiter="\t", names=["topic", "Q0", "docid", "rank", "score", "run"])

# %%
infos = {}
for topic in set(gsdf["trec_topic_number"]):
    gsreldocs      = set(gsdf.query("trec_topic_number == " + str(topic) +" and relevance_score > 0")["trec_doc_id"])
    res4topic      = resdf.query("topic == " + str(topic) + "")
    allfoundseries = res4topic["docid"]
    resdocs        = set(allfoundseries)
    info["topic"]       = topic
    info["rel"]         = gsreldocs
    info["relfound"]    = gsreldocs.intersection(resdocs)
    info["relnotfound"] = gsreldocs.difference(resdocs)
    info["allfound"]    = list(allfoundseries)
    info["allranks"]    = list(res4topic["rank"])
    infos[topic] = info

# %%
reltop5 = gsdf.query("trec_topic_number == 5 and relevance_score > 0").sort_values("relevance_score", ascending=False)
rest5   = resdf.query("topic == 5")
cols = ["trec_topic_number", "trec_doc_id", "pm_rel_desc", "disease_desc", "gene1_annotation_desc", "gene1_name", "gene2_annotation_desc", "gene2_name", "relevance_score"]
pd.merge(reltop5[cols], rest5, left_on="trec_doc_id", right_on="docid", how="left").sort_values("rank", ascending=True)
# Out:
#     trec_topic_number     trec_doc_id pm_rel_desc   disease_desc  \
# 41                  5        25407517    Human PM          Exact
# 7                   5        23403819    Human PM          Exact
# 34                  5        26924424    Human PM          Exact
# 35                  5        26600396    Human PM          Exact
# 2                   5        24535907    Human PM          Exact
# 18                  5        21635872    Human PM          Exact
# 43                  5  AACR_2016-1138    Human PM          Exact
# 17                  5        21639808    Human PM          Exact
# 10                  5        22535154    Human PM          Exact
# 3                   5        24471189    Human PM          Exact
# 31                  5        27009410    Human PM  More Specific
# 39                  5        25643238    Human PM          Exact
# 4                   5        23833299    Human PM          Exact
# 27                  5        27219630    Human PM          Exact
# 13                  5        22235286    Human PM          Exact
# 6                   5        23550516    Human PM          Exact
# 65                  5        20460471    Human PM          Exact
# 28                  5        27210749    Human PM          Exact
# 26                  5        27488807    Human PM          Exact
# 52                  5        16977458    Human PM          Exact
# 33                  5        25399551    Human PM          Exact
# 40                  5        25607474    Human PM          Exact
# 22                  5        20818844    Human PM          Exact
# 23                  5        26997441    Human PM          Exact
# 20                  5        24614711    Human PM          Exact
# 64                  5        20425073    Human PM          Exact
# 29                  5        27194985    Human PM          Exact
# 9                   5        22962325    Human PM          Exact
# 54                  5        17001621    Human PM          Exact
# 14                  5        21905615    Human PM          Exact
# ..                ...             ...         ...            ...
# 67                  5        20687502    Human PM          Exact
# 51                  5        11500806    Human PM          Exact
# 12                  5        22356324    Human PM          Exact
# 77                  5        14691295    Human PM  More Specific
# 37                  5        26141748    Human PM          Exact
# 86                  5        20350535    Human PM          Exact
# 53                  5        16988943    Human PM          Exact
# 59                  5        17570501    Human PM          Exact
# 5                   5        23771122    Human PM          Exact
# 68                  5        15883616    Human PM          Exact
# 15                  5        21793228    Human PM          Exact
# 88                  5        20629085    Human PM          Exact
# 89                  5        10400925    Human PM   More General
# 19                  5        21412176    Human PM  More Specific
# 74                  5        12873990    Human PM          Exact
# 73                  5        10630172    Human PM   More General
# 63                  5        10775844    Human PM          Exact
# 56                  5        12925390    Human PM          Exact
# 48                  5        12107107    Human PM          Exact
# 79                  5        15191558    Human PM          Exact
# 70                  5        12619120    Human PM          Exact
# 24                  5  AACR_2013-2078    Human PM          Exact
# 42                  5        21110341    Human PM          Exact
# 80                  5        10620109    Human PM          Exact
# 72                  5        10753192   Animal PM   More General
# 50                  5        16880792    Human PM          Exact
# 81                  5        16687919    Human PM   More General
# 32                  5        26984828    Human PM          Exact
# 87                  5        20526349    Human PM   More General
# 85                  5        21912429    Human PM   More General
#
#    gene1_annotation_desc    gene1_name gene2_annotation_desc       gene2_name  \
# 41                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 7                  Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 34                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 35                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 2                  Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 18                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 43                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 17                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 10                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 3                  Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 31                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 39                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 4                  Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 27                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 13                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 6                  Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 65                 Exact  BRAF (V600E)                 Exact  CDKN2A Deletion
# 28                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 26                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 52          Missing Gene  BRAF (V600E)                 Exact  CDKN2A Deletion
# 33                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 40                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 22                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 23                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 20                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 64                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 29                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 9                  Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 54          Missing Gene  BRAF (V600E)                 Exact  CDKN2A Deletion
# 14                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# ..                   ...           ...                   ...              ...
# 67          Missing Gene  BRAF (V600E)                 Exact  CDKN2A Deletion
# 51          Missing Gene  BRAF (V600E)                 Exact  CDKN2A Deletion
# 12                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 77     Different Variant  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 37                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 86       Missing Variant  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 53          Missing Gene  BRAF (V600E)                 Exact  CDKN2A Deletion
# 59                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 5                  Exact  BRAF (V600E)                 Exact  CDKN2A Deletion
# 68       Missing Variant  BRAF (V600E)                 Exact  CDKN2A Deletion
# 15                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 88       Missing Variant  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 89     Different Variant  BRAF (V600E)                 Exact  CDKN2A Deletion
# 19          Missing Gene  BRAF (V600E)                 Exact  CDKN2A Deletion
# 74     Different Variant  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 73     Different Variant  BRAF (V600E)                 Exact  CDKN2A Deletion
# 63     Different Variant  BRAF (V600E)                 Exact  CDKN2A Deletion
# 56          Missing Gene  BRAF (V600E)                 Exact  CDKN2A Deletion
# 48          Missing Gene  BRAF (V600E)                 Exact  CDKN2A Deletion
# 79     Different Variant  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 70       Missing Variant  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 24                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 42                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 80     Different Variant  BRAF (V600E)     Different Variant  CDKN2A Deletion
# 72     Different Variant  BRAF (V600E)                 Exact  CDKN2A Deletion
# 50       Missing Variant  BRAF (V600E)                 Exact  CDKN2A Deletion
# 81       Missing Variant  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 32                 Exact  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 87       Missing Variant  BRAF (V600E)          Missing Gene  CDKN2A Deletion
# 85          Missing Gene  BRAF (V600E)                 Exact  CDKN2A Deletion
#
#     relevance_score  topic  Q0           docid  rank       score          run
# 41                2      5  Q0        25407517     1  111.230186  genedispbnb
# 7                 2      5  Q0        23403819     2   96.344284  genedispbnb
# 34                2      5  Q0        26924424     5   87.982727  genedispbnb
# 35                2      5  Q0        26600396     7   86.931015  genedispbnb
# 2                 2      5  Q0        24535907    12   84.935699  genedispbnb
# 18                2      5  Q0        21635872    16   84.486534  genedispbnb
# 43                2      5  Q0  AACR_2016-1138    19   83.977386  genedispbnb
# 17                2      5  Q0        21639808    20   83.548668  genedispbnb
# 10                2      5  Q0        22535154    29   81.909706  genedispbnb
# 3                 2      5  Q0        24471189    30   81.904175  genedispbnb
# 31                2      5  Q0        27009410    33   81.296173  genedispbnb
# 39                2      5  Q0        25643238    46   79.135666  genedispbnb
# 4                 2      5  Q0        23833299    57   77.617119  genedispbnb
# 27                2      5  Q0        27219630    71   76.036903  genedispbnb
